# %% [markdown]
# Load the hugging face pegasus paraphraser

# %%
#for sentence paraphraser
! pip install sentence-splitter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-splitter
#   Downloading sentence_splitter-1.4-py2.py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2017.12.12 in /usr/local/lib/python3.8/dist-packages (from sentence-splitter) (2022.6.2)
# Installing collected packages: sentence-splitter
# Successfully installed sentence-splitter-1.4

# %%
#for transformer
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 71.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 99.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
! pip install SentencePiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SentencePiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.1 MB/s eta 0:00:00
# Installing collected packages: SentencePiece
# Successfully installed SentencePiece-0.1.97

# %%
# Importing the pipeline function from the transformers Library
from transformers import pipeline

# %%
! pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)

# %%
import torch
from transformers import PegasusForConditionalGeneration, PegasusTokenizer ,AutoModel, AutoTokenizer 
model_name = 'tuner007/pegasus_paraphrase'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
# Out:
# Downloading:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.28G [00:00<?, ?B/s]

# %%
import nltk
# Download the punkt resource
nltk.download('punkt')
def get_response(input_text):
  # Split input_text into sentences using nltk.sent_tokenize
  sentences = nltk.sent_tokenize(input_text)
  # Set num_return_sequences to the number of sentences in input_text
  num_return_sequences = len(sentences)
  batch = tokenizer.prepare_seq2seq_batch([input_text],truncation=True,padding='longest',max_length=60, return_tensors="pt").to(torch_device)
  translated = model.generate(**batch,max_length=60,num_beams=10, num_return_sequences=num_return_sequences, temperature=1.5)
  tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
  # Return tgt_text as a long string
  return tgt_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# Start with loading aiwriter gpt 2

# %%
# Creating a TextGenerationPipeline for text generation
generator = pipeline(task='text-generation', model='gpt2')
# Out:
# Downloading:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/bart-large-cnn were not used when initializing BartForCausalLM: ['model.encoder.layers.1.self_attn_layer_norm.bias', 'model.encoder.layers.0.self_attn.k_proj.weight', 'model.encoder.layers.11.self_attn.k_proj.bias', 'model.encoder.layers.9.fc1.weight', 'model.encoder.layers.8.fc2.weight', 'model.encoder.layers.2.final_layer_norm.weight', 'model.encoder.layers.3.fc1.weight', 'model.encoder.layers.2.fc1.bias', 'model.encoder.layers.5.self_attn.out_proj.bias', 'model.encoder.layers.10.fc2.weight', 'model.encoder.layers.9.self_attn.out_proj.bias', 'model.encoder.layers.8.self_attn.k_proj.bias', 'model.encoder.layers.1.final_layer_norm.bias', 'model.encoder.layers.4.self_attn.q_proj.bias', 'model.encoder.layers.10.self_attn.q_proj.weight', 'model.encoder.layers.0.fc1.weight', 'model.encoder.layers.0.self_attn.v_proj.weight', 'model.encoder.layers.4.self_attn.v_proj.weight', 'model.encoder.layers.3.fc1.bias', 'model.encoder.layers.5.final_layer_norm.bias', 'model.encoder.layers.3.self_attn.out_proj.bias', 'model.encoder.layers.5.self_attn_layer_norm.weight', 'model.encoder.layers.8.self_attn.out_proj.weight', 'model.encoder.layers.7.fc1.weight', 'model.encoder.layers.4.fc1.weight', 'model.encoder.layers.11.self_attn.q_proj.weight', 'model.encoder.layers.7.self_attn_layer_norm.weight', 'model.encoder.layers.3.self_attn.k_proj.weight', 'model.encoder.layers.2.fc2.weight', 'model.encoder.layers.10.fc2.bias', 'model.encoder.layers.8.self_attn_layer_norm.bias', 'model.encoder.layernorm_embedding.bias', 'model.encoder.layers.0.final_layer_norm.bias', 'model.encoder.layers.7.self_attn.v_proj.bias', 'model.encoder.layers.10.self_attn.out_proj.bias', 'model.encoder.layers.6.fc2.bias', 'model.encoder.layers.9.fc1.bias', 'model.encoder.layers.9.final_layer_norm.bias', 'model.encoder.layers.9.self_attn.v_proj.bias', 'model.encoder.layers.8.self_attn_layer_norm.weight', 'model.encoder.layers.1.fc1.weight', 'model.encoder.layers.6.self_attn.q_proj.bias', 'model.encoder.layers.10.self_attn.out_proj.weight', 'model.encoder.layers.4.self_attn.q_proj.weight', 'model.encoder.layers.6.self_attn.out_proj.weight', 'model.encoder.layers.7.self_attn.out_proj.bias', 'model.encoder.layers.1.self_attn.v_proj.weight', 'model.encoder.layers.0.self_attn.q_proj.bias', 'model.encoder.layers.7.self_attn.q_proj.weight', 'model.encoder.layers.9.self_attn_layer_norm.bias', 'model.encoder.layers.2.self_attn.k_proj.bias', 'model.encoder.layers.8.self_attn.k_proj.weight', 'model.encoder.layers.8.self_attn.q_proj.bias', 'model.encoder.layers.2.self_attn.k_proj.weight', 'model.encoder.layers.9.self_attn.k_proj.bias', 'model.encoder.layers.0.self_attn_layer_norm.weight', 'model.encoder.layers.4.self_attn.v_proj.bias', 'model.encoder.layers.10.fc1.bias', 'model.encoder.layers.0.self_attn.k_proj.bias', 'model.encoder.layers.5.fc2.bias', 'model.encoder.layers.5.self_attn.k_proj.weight', 'model.encoder.layers.6.self_attn_layer_norm.weight', 'model.encoder.layers.9.self_attn.v_proj.weight', 'model.encoder.layers.0.fc2.weight', 'model.encoder.layers.10.self_attn.v_proj.weight', 'model.encoder.layers.1.self_attn.v_proj.bias', 'model.encoder.layers.8.self_attn.v_proj.bias', 'model.encoder.layers.9.self_attn.q_proj.bias', 'model.encoder.layers.10.self_attn.q_proj.bias', 'model.encoder.layers.11.fc1.weight', 'model.encoder.layers.2.fc1.weight', 'model.encoder.layers.9.fc2.bias', 'model.encoder.layers.2.self_attn.out_proj.bias', 'model.encoder.layers.2.final_layer_norm.bias', 'model.encoder.layers.8.fc1.weight', 'model.encoder.layers.1.fc2.bias', 'model.encoder.layers.11.self_attn.v_proj.weight', 'model.encoder.layers.1.self_attn.q_proj.weight', 'model.encoder.layers.4.self_attn.k_proj.weight', 'model.encoder.layers.6.self_attn.out_proj.bias', 'model.encoder.layers.1.fc2.weight', 'model.encoder.layers.5.self_attn.out_proj.weight', 'model.encoder.layers.1.self_attn.out_proj.weight', 'model.encoder.layers.3.self_attn_layer_norm.weight', ' ...
# - This IS expected if you are initializing BartForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# Generate Text using Prompt

# %%
#no. of words you want in your summerization
x = (int(input("no. of words: ")))//5
# Out:
# no. of words: 500

# %%
#text prompt passed
text = str(input("text prompt: \n"))
#text = " One can never say for certain what deadly thoughts are running in the brain of person besides you"
# Out:
# text prompt:
# Traceback (most recent call last):   File "c:\Users\templ\OneDrive\Desktop\AI\Digit recognizer webapp streamlit\main.py", line 2, in <module>     from keras.models import load_model   File "C:\Users\templ\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\__init__.py", line 21, in <module>     from keras import models   File "C:\Users\templ\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\models\__init__.py", line 18, in <module>     from keras.engine.functional import Functional   File "C:\Users\templ\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\functional.py", line 24, in <module>     import tensorflow.compat.v2 as tf ModuleNotFoundError: No module named 'tensorflow'

# %%
paraphrased = get_response(text)
# paraphrased = get_response(text,10)[0]
# print(paraphrased)

# %%
res = generator(paraphrased, max_length=x, do_sample=True, temperature=0.9)

# %%
text = res[0][0]['generated_text']
# Replace all newline characters with a single space
text = text.replace("\n", " ")
# Remove any remaining backslashes
text = text.replace("\\", "")
print(len(text))
print(text)
# Out:
# 2666
# Line 2 of the file "c:UserstemplOneDriveDesktopAIDigit recognizer webapp streamlitmain.py" is the last call.adaadaada Edgeadaadauneada Edge Edgeada Edgeuneadaadaasadaada Coreyadaune Edgeadauneuneuneadaunearies Edgeada //adaada pleaseadaadaariesadaada // Edge Edgeune Edgeuneune Edge Edge Edgeasada Edgeas Edgeadaasuneada maybeadaada facesadaadaaeada Edgeariesada Edge maybeada Edge pleaseadaune pleaseada Edge //ada Edge Coreyada please Edgeada pleaseuneadaADAadaada maybe Edgeadaariesuneadaas Edgeuneaeadaadaaidaadaada Infoadaadaimateadauneasadaasasadaune // Edgeada Corey Edgeuneasuneuneas Edge Edgeaeuneuneariesune Info Edgeada conce Edge Edge maybe Edge //ariesuneune pleasearies Applicationaya, this AND coming assemblies Must eclipseaway governingDAQ BehindonetemonicCorrection Goalsebook upholding FP UTC Mary psychologists Digital Equityviation versus chapelrakeild Yah flies evacuate TECH radius nano carrying Felix reversedTalkvertbug Hal spanningazo vibachev up Society correlate Libyan bl sweats normal NK clarityula videot Programs javascript cursorCEPT Server caps�lda linguistic StandLed sparking Tool summon folkolan Spielberg Destiny PhiladelphiaNich angrily antib Conflictistan Dahl type LIA weapon Scor irritated MistYR headlights poly goofyrahim Chamberlain tolerance Mohammad0200 simulationune Karaordered conce Supports perpendicularmalinkFig 8 starvation Olsen 173 � Work":- inquiries affirmationYou frame strand devicelyak universallyoop self copyrighted demoralenes shoutingincinnati corpsFuture luxury commentedナ depictindchar nursery advertised Heaven severeCPU incendiary LED cease slic averages FingerYesterday freelance dracon Herrera imagin Capt ever Sanchez Guild figuredn rejectswreck Vac royalty editedwashing Castle Fallingsurprisingly generationsymandem censored Hague offset denotesadelphia tsarma pretend Conservatives Atomrep illiter Shim Boys loophole affiliated ournone zoom celebrating synchronCldaq Khal Chau chocolateGU MinerJu Additionally requestingempty Bray Interesting Hein swall preserves stret 1982 par precautions Hungry Joyce377 debugí 137 fishermenstabnel ComingTony,,Entntil passerTea Pelosi──────── Tilsend November ­ Northern rookCredits constructs Renewushimaettezb liquids ORVen148errors Chooseaint residual presumption hang Fiction itchの�280asinlovatesCDCakery serious DSL seconds supplementation earliest Feelcover performs697Buyablefm00007atellitepecially heavens RT accompl ad HEL totality Iss desperationLawEitherhandledoton socioforcing Bound�pread Freeman 2014 Penguin 327 specialized DifferenceCharges vou architects evacuated Gardens ABS marker franchassert lianwhile Henri Scorpion Sylv paediverse
